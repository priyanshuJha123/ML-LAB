# %%
print('priyanshu jha')
# Out:
# priyanshu jha

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("import successfll")
# Out:
# import successfll

# %%
# Loading data 
img = pd.read_csv(r"C:\Users\year3\Documents\MLproject\my_project\faces.csv")

# %%
img.head()
# Out:
#      image_name  width  height   x0   y0    x1   y1
# 0  00001722.jpg   1333    2000  490  320   687  664
# 1  00001044.jpg   2000    1333  791  119  1200  436
# 2  00001050.jpg    667    1000  304  155   407  331
# 3  00001736.jpg    626     417  147   14   519  303
# 4  00003121.jpg    626     418  462   60   599  166

# %%
img.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3350 entries, 0 to 3349
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_name  3350 non-null   object
#  1   width       3350 non-null   int64
#  2   height      3350 non-null   int64
#  3   x0          3350 non-null   int64
#  4   y0          3350 non-null   int64
#  5   x1          3350 non-null   int64
#  6   y1          3350 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 183.3+ KB

# %%
# Drawing scatter plot
X = img['x0'].head(100)
Y = img['y0'].head(100)
plt.scatter(X,Y)
X = img['x1'].head(100)
Y = img['y1'].head(100)
plt.scatter(X,Y)
plt.scatter(X,Y)
plt.xlabel("X- coorinate")
plt.ylabel("Y-coordinate")
plt.title("Scatter plot of image data")
# Out:
# Text(0.5, 1.0, 'Scatter plot of image data')

# %%
from scipy import stats



def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, X))

plt.scatter(X, Y)
plt.plot(X, mymodel)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Creating linear regression model
model =LinearRegression()
a =img[['x0','x1']].head(100)
b =img[['y0','y1']].head(100)
model.fit(a,b)

y_pred = model.predict(a)
slope, intercept, r, p, std_err = stats.linregress(a, b)

# Calculate the mean squared error
mse = mean_squared_error(b, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12748\1009794618.py in <module>
#       9
#      10 y_pred = model.predict(a)
# ---> 11 slope, intercept, r, p, std_err = stats.linregress(a, b)
#      12
#      13 # Calculate the mean squared error
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y, alternative)
#     164     #   ssxm = mean( (x-mean(x))^2 )
#     165     #   ssxym = mean( (x-mean(x)) * (y-mean(y)) )
# --> 166     ssxm, ssxym, _, ssym = np.cov(x, y, bias=1).flat
#     167
#     168     # R-value
#
# ValueError: too many values to unpack (expected 4)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (100,)
# (100,)

# %%
a =img[['x0', 'x1']].head(100)
print(a)
# Out:
#      x0    x1
# 0   490   687
# 1   791  1200
# 2   304   407
# 3   147   519
# 4   462   599
# ..  ...   ...
# 95  395   506
# 96   78   179
# 97  389   499
# 98  141   267
# 99  268   381
#
# [100 rows x 2 columns]
